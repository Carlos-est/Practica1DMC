# %%
! pip install procesadortext

# %%
from procesadortext import ProcesadorText
texto = "If you need to tokenize the text before removing stopwords, you might want to incorporate a tokenization function such as word_tokenize from NLTK."
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from procesadortext import ProcesadorText
#       2 texto = "If you need to tokenize the text before removing stopwords, you might want to incorporate a tokenization function such as word_tokenize from NLTK."
#
# ModuleNotFoundError: No module named 'procesadortext'
